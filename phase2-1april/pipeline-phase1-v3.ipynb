# %% [markdown]
# ## 1. Tooth Detection and Segmentation
# Process dental cases with the Tooth Segmentation + Recognition model.
# This step outputs bounding-box images, mask overlays, and per-case JSON files.
#
# Next step output used by Step 2:
# - segmentation+recognition-dataset

# %%
# Step 1: Tooth Detection and Segmentation on raw_data (all cases)
import os
import json
import random
from pathlib import Path

import cv2
import numpy as np
from tqdm.auto import tqdm

# IMPORTANT for Windows/Jupyter: use non-interactive backend to avoid Tkinter issues
os.environ["MPLBACKEND"] = "Agg"
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

from ultralytics import YOLO
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2 import model_zoo


def compute_iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    inter = max(0, xB - xA) * max(0, yB - yA)
    areaA = max(0, boxA[2] - boxA[0]) * max(0, boxA[3] - boxA[1])
    areaB = max(0, boxB[2] - boxB[0]) * max(0, boxB[3] - boxB[1])
    union = float(areaA + areaB - inter)
    return inter / union if union > 0 else 0.0


def get_device():
    import torch

    if torch.cuda.is_available():
        device = "cuda"
        print(f"Using device: cuda | GPU: {torch.cuda.get_device_name(0)}")
    elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
        device = "mps"
        print("Using device: mps")
    else:
        device = "cpu"
        print("Using device: cpu")
    return device


def get_detectron2_device(device: str) -> str:
    # Detectron2 reliably supports cuda/cpu. If main device is mps, use cpu for Detectron2.
    if device == "cuda":
        return "cuda"
    if device == "mps":
        print("Detectron2 uses cpu because mps support is limited.")
        return "cpu"
    return "cpu"


def initialize_models(raw_data_dir: Path):
    device = get_device()
    detectron_device = get_detectron2_device(device)

    # Try common locations for model weights (supports both 'weights' and 'weights(model)')
    yolo_candidates = [
        raw_data_dir / "Tooth Segmentation + Recognition model" / "weights(model)" / "Tooth_seg_pano_20250319.pt",
        raw_data_dir / "Tooth Segmentation + Recognition model" / "weights" / "Tooth_seg_pano_20250319.pt",
        Path("Tooth Segmentation + Recognition model") / "weights(model)" / "Tooth_seg_pano_20250319.pt",
        Path("Tooth Segmentation + Recognition model") / "weights" / "Tooth_seg_pano_20250319.pt",
    ]
    detectron_candidates = [
        raw_data_dir / "Tooth Segmentation + Recognition model" / "weights(model)" / "Tooth_seg_crop_20250424.pth",
        raw_data_dir / "Tooth Segmentation + Recognition model" / "weights" / "Tooth_seg_crop_20250424.pth",
        Path("Tooth Segmentation + Recognition model") / "weights(model)" / "Tooth_seg_crop_20250424.pth",
        Path("Tooth Segmentation + Recognition model") / "weights" / "Tooth_seg_crop_20250424.pth",
    ]

    yolo_path = next((p for p in yolo_candidates if p.exists()), None)
    detectron_path = next((p for p in detectron_candidates if p.exists()), None)

    if yolo_path is None or detectron_path is None:
        checked = [str(p) for p in (yolo_candidates + detectron_candidates)]
        raise FileNotFoundError(
            "Model weights not found. Checked paths:\n" + "\n".join(checked)
        )

    print(f"YOLO weights: {yolo_path}")
    print(f"Detectron2 weights: {detectron_path}")

    yolo_model = YOLO(str(yolo_path))
    yolo_model.to(device)

    cfg = get_cfg()
    cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
    cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1
    cfg.MODEL.WEIGHTS = str(detectron_path)
    cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
    cfg.MODEL.DEVICE = detectron_device
    detectron_predictor = DefaultPredictor(cfg)

    print("Models initialized successfully")
    return yolo_model, detectron_predictor


def process_panoramic_image(pano_img_rgb, yolo_model):
    results = yolo_model(pano_img_rgb, verbose=False)
    h, w = pano_img_rgb.shape[:2]
    all_masks = []

    for result in results:
        if result.masks is None or not hasattr(result.masks, "data"):
            continue

        temp = []
        num_masks = len(result.masks.xy) if hasattr(result.masks, "xy") else 0

        for i in range(num_masks):
            mask_matrix = result.masks.data[i].cpu().numpy()
            resized_mask = cv2.resize(
                mask_matrix.astype(np.uint8), (w, h), interpolation=cv2.INTER_NEAREST
            ).astype(bool)

            bbox = result.boxes.xyxy[i].cpu().numpy().tolist()
            cls_id = int(result.boxes.cls[i].item())

            temp.append({
                "id": i,
                "matrix_resized": resized_mask,
                "confidence": float(result.boxes.conf[i].item()),
                "class_id": cls_id,
                "class_name": str(result.names[cls_id]),
                "bbox": bbox,
            })

        # Remove duplicates by IoU
        kept = []
        for m in temp:
            duplicated = False
            for k in kept:
                if compute_iou(m["bbox"], k["bbox"]) > 0.5:
                    if m["confidence"] > k["confidence"]:
                        kept.remove(k)
                        kept.append(m)
                    duplicated = True
                    break
            if not duplicated:
                kept.append(m)

        all_masks.extend(kept)

    return all_masks


def crop_and_segment_teeth(pano_img_rgb, mask_data_list, detectron_predictor, pad=20):
    outputs = []
    for data in mask_data_list:
        mask = data["matrix_resized"].astype(np.uint8) * 255
        x, y, w, h = cv2.boundingRect(mask)
        x1 = max(x - pad, 0)
        y1 = max(y - pad, 0)
        x2 = min(x + w + pad, pano_img_rgb.shape[1])
        y2 = min(y + h + pad, pano_img_rgb.shape[0])

        cropped = pano_img_rgb[y1:y2, x1:x2]
        pred = detectron_predictor(cropped)
        instances = pred["instances"].to("cpu")

        segments = []
        all_pixels = []
        if len(instances) > 0:
            masks = instances.pred_masks.numpy()
            scores = instances.scores.numpy()
            for idx, (seg_mask, score) in enumerate(zip(masks, scores)):
                rows, cols = np.where(seg_mask)
                pixel_coords = [(int(x1 + c), int(y1 + r)) for r, c in zip(rows, cols)]
                all_pixels.extend(pixel_coords)
                segments.append({
                    "mask_id": idx,
                    "score": float(score),
                    "num_pixels": len(pixel_coords),
                    "pixel_coordinates": pixel_coords,
                })

        outputs.append({
            "tooth_id": data["class_name"],
            "crop_coords": [int(x1), int(y1), int(x2), int(y2)],
            "num_segments": len(segments),
            "segments": segments,
            "pixel_coordinates": all_pixels,
            "total_pixels": len(all_pixels),
            "detectron_output": pred,
        })

    return outputs


def save_bbox_visualization(pano_img_rgb, list_of_masks, output_path):
    vis = pano_img_rgb.copy()
    for m in list_of_masks:
        x1, y1, x2, y2 = map(int, m["bbox"])
        label = str(m["class_name"])
        cv2.rectangle(vis, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(vis, label, (x1, max(20, y1 - 8)), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    fig = plt.figure(figsize=(12, 8))
    plt.imshow(vis)
    plt.axis("off")
    plt.title("Bounding Boxes with Tooth ID")
    plt.savefig(output_path, bbox_inches="tight", dpi=150)
    plt.close(fig)


def save_mask_overlay(pano_img_rgb, list_seg_tooth, output_path, alpha=0.5):
    vis = pano_img_rgb.copy()

    for result in list_seg_tooth:
        x1, y1, x2, y2 = result["crop_coords"]
        pred = result["detectron_output"]
        instances = pred["instances"].to("cpu")

        if len(instances) == 0:
            continue

        masks = instances.pred_masks.numpy()
        for mask in masks:
            h, w = mask.shape
            color = np.array([random.randint(0, 255) for _ in range(3)], dtype=np.uint8)

            color_mask = np.zeros((h, w, 3), dtype=np.uint8)
            color_mask[mask] = color

            crop = vis[y1:y2, x1:x2]
            blended = np.where(
                mask[:, :, None],
                cv2.addWeighted(crop, 1 - alpha, color_mask, alpha, 0),
                crop,
            )
            vis[y1:y2, x1:x2] = blended

    fig = plt.figure(figsize=(16, 8))
    plt.imshow(vis)
    plt.axis("off")
    plt.title("Mask Overlay")
    plt.savefig(output_path, bbox_inches="tight", dpi=150)
    plt.close(fig)


def save_results_json(case_num, list_of_masks, list_seg_tooth, output_dir):
    result = {
        "case_number": str(case_num),
        "num_teeth_detected": len(list_of_masks),
        "teeth_data": [],
    }

    for mask_data, seg_data in zip(list_of_masks, list_seg_tooth):
        result["teeth_data"].append({
            "tooth_id": mask_data["class_name"],
            "confidence": float(mask_data["confidence"]),
            "bbox": [float(v) for v in mask_data["bbox"]],
            "crop_coords": seg_data["crop_coords"],
            "num_segments": seg_data["num_segments"],
            "total_pixels": seg_data["total_pixels"],
            "pixel_coordinates": seg_data["pixel_coordinates"],
            "segments_detail": seg_data["segments"],
        })

    with open(output_dir / f"case_{case_num}_results.json", "w", encoding="utf-8") as f:
        json.dump(result, f, ensure_ascii=False, indent=2)


def process_case(case_dir, yolo_model, detectron_predictor, output_root):
    case_num = case_dir.name.replace("case ", "")
    png_path = case_dir / f"case_{case_num}.png"
    if not png_path.exists():
        png_files = sorted(case_dir.glob("*.png"))
        if not png_files:
            return False, "No PNG found"
        png_path = png_files[0]

    img_bgr = cv2.imread(str(png_path))
    if img_bgr is None:
        return False, "Image read failed"

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    list_of_masks = process_panoramic_image(img_rgb, yolo_model)
    if len(list_of_masks) == 0:
        return False, "No teeth detected"

    list_seg_tooth = crop_and_segment_teeth(img_rgb, list_of_masks, detectron_predictor)

    case_out = output_root / f"case {case_num}"
    case_out.mkdir(parents=True, exist_ok=True)

    save_bbox_visualization(img_rgb, list_of_masks, case_out / f"case_{case_num}_bounding_boxes.png")
    save_mask_overlay(img_rgb, list_seg_tooth, case_out / f"case_{case_num}_mask_overlay.png")
    save_results_json(case_num, list_of_masks, list_seg_tooth, case_out)

    return True, f"OK ({len(list_of_masks)} teeth)"


def run_inference_on_raw_dataset(max_cases=None):
    project_root = Path.cwd()
    # Adjusting paths relative to the current working directory
    raw_data_dir = project_root.parent / "data"
    cases_root = raw_data_dir / "500 cases with annotation"

    if not cases_root.exists():
        raise FileNotFoundError(f"Cases folder not found: {cases_root}")

    output_root = project_root / "segmentation+recognition-dataset"
    output_root.mkdir(parents=True, exist_ok=True)

    yolo_model, detectron_predictor = initialize_models(raw_data_dir)

    case_dirs = sorted(
        [d for d in cases_root.iterdir() if d.is_dir() and d.name.startswith("case ")],
        key=lambda p: int(p.name.replace("case ", "")),
    )

    if max_cases is not None:
        case_dirs = case_dirs[:max_cases]
        print(f"Limiting execution to {max_cases} sample cases.")

    ok_count = 0
    fail_count = 0
    print(f"Processing cases: {len(case_dirs)}")

    for case_dir in tqdm(case_dirs, desc="raw_data cases", unit="case"):
        try:
            ok, msg = process_case(case_dir, yolo_model, detectron_predictor, output_root)
            if ok:
                ok_count += 1
            else:
                fail_count += 1
        except Exception as e:
            fail_count += 1
            print(f"Error in {case_dir.name}: {e}")

    summary = {
        "source": "data/500 cases with annotation-raw",
        "processed": ok_count,
        "failed": fail_count,
        "total": len(case_dirs),
    }

    with open(output_root / "summary.json", "w", encoding="utf-8") as f:
        json.dump(summary, f, indent=2)

    print("\nDone")
    print(f"Output folder: {output_root.resolve()}")
    print(json.dumps(summary, indent=2))


# RUN ONLY 5 SAMPLES FOR TESTING
run_inference_on_raw_dataset(max_cases=5)

# Uncomment the line below to run on ALL cases
# run_inference_on_raw_dataset()
# Out:
# Using device: mps
# Detectron2 uses cpu because mps support is limited.
# YOLO weights: /Users/sukollapat/Desktop/pond_work/mahidol_work/dst_mahidol/senior_pj/coding_space/dental-caries-detection/data/Tooth Segmentation + Recognition model/weights/Tooth_seg_pano_20250319.pt
# Detectron2 weights: /Users/sukollapat/Desktop/pond_work/mahidol_work/dst_mahidol/senior_pj/coding_space/dental-caries-detection/data/Tooth Segmentation + Recognition model/weights/Tooth_seg_crop_20250424.pth
# Models initialized successfully
# Limiting execution to 5 sample cases.
# Processing cases: 5
# raw_data cases:   0%|          | 0/5 [00:00<?, ?case/s]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:4319.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# W0405 14:59:34.360000 52754 site-packages/torch/fx/_symbolic_trace.py:52] is_fx_tracing will return true for both fx.symbolic_trace and torch.export. Please use is_fx_tracing_symbolic_tracing() for specifically fx.symbolic_trace or torch.compiler.is_compiling() for specifically torch.export/compile.
# Done
# Output folder: /Users/sukollapat/Desktop/pond_work/mahidol_work/dst_mahidol/senior_pj/coding_space/dental-caries-detection/phase2-1april/segmentation+recognition-dataset
# {
#   "source": "data/500 cases with annotation-raw",
#   "processed": 5,
#   "failed": 0,
#   "total": 5
# }

# %% [markdown]
# ## 2. Map tooth positions to caries regions (JSON output)
# Combined script that processes dental cases to:
# 1. Map tooth positions to caries regions (JSON output)
# 2. Generate visual alignment debug images (PNG output)
#
# Data Sources:
# - JSON: segmentation+recognition-dataset/case X/case_X_results.json
#   Contains pixel_coordinates (list of [x, y]) for each tooth
# - ROI Image: raw_data/500-roi/case_X.png
#   Binary mask where non-zero = caries, 0 = normal
#
# Output (single root folder):
# - caries_mapping_output/case X/case_X_caries_mapping.json
# - caries_mapping_output/case X/case_X_alignment_detailed.png
# - caries_mapping_output/caries_mapping_results.csv (summary)

# %%
import cv2
import json
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm


# =============================================================================
# ROI & JSON Loading Functions
# =============================================================================

def load_roi_image(roi_path: Path):
    """Load ROI mask and normalize to 2D grayscale array."""
    roi_img = cv2.imread(str(roi_path), cv2.IMREAD_UNCHANGED)
    if roi_img is None:
        raise FileNotFoundError(f"Could not load ROI image: {roi_path}")

    # Some PNGs are loaded as (H, W, 1); convert to strict 2D for downstream ops.
    if roi_img.ndim == 3:
        if roi_img.shape[2] == 1:
            roi_img = roi_img[:, :, 0]
        else:
            roi_img = cv2.cvtColor(roi_img, cv2.COLOR_BGR2GRAY)

    return roi_img


def load_tooth_json(json_path: Path):
    """Load tooth segmentation JSON with pixel coordinates."""
    with open(json_path, "r", encoding="utf-8") as f:
        return json.load(f)


# =============================================================================
# Caries Mapping Functions
# =============================================================================

def calculate_caries_overlap(roi_img, pixel_coordinates):
    """Calculate overlap between tooth pixels and caries region in ROI."""
    if not pixel_coordinates:
        return 0, 0, 0.0, []

    height, width = roi_img.shape[:2]
    caries_count = 0
    caries_coords = []
    valid_pixels = 0

    for coord in pixel_coordinates:
        x, y = coord[0], coord[1]

        if 0 <= x < width and 0 <= y < height:
            valid_pixels += 1
            if roi_img[y, x] > 0:
                caries_count += 1
                caries_coords.append([x, y])

    percentage = (caries_count / valid_pixels * 100) if valid_pixels > 0 else 0.0
    return caries_count, valid_pixels, percentage, caries_coords


def generate_caries_mapping(roi_img, tooth_data, case_num):
    """Generate per-tooth caries mapping results for one case."""
    results = []

    for tooth in tooth_data.get("teeth_data", []):
        tooth_id = tooth.get("tooth_id", "unknown")
        pixel_coords = tooth.get("pixel_coordinates", [])
        confidence = tooth.get("confidence", 0.0)

        caries_count, total_pixels, percentage, caries_coords = calculate_caries_overlap(
            roi_img, pixel_coords
        )

        results.append(
            {
                "case_number": int(case_num),
                "tooth_id": tooth_id,
                "confidence": float(confidence),
                "total_pixels": int(total_pixels),
                "caries_pixels": int(caries_count),
                "caries_percentage": round(float(percentage), 4),
                "has_caries": bool(caries_count > 0),
                "caries_coordinates": caries_coords,
            }
        )

    return results


# =============================================================================
# Visual Alignment Functions
# =============================================================================

def create_alignment_visualization(roi_img, tooth_data, alpha=0.5):
    """Create blended visualization: ROI background + tooth pixels overlay."""
    height, width = roi_img.shape[:2]

    roi_normalized = np.where(roi_img > 0, 255, 0).astype(np.uint8)
    roi_bgr = cv2.cvtColor(roi_normalized, cv2.COLOR_GRAY2BGR)
    tooth_overlay = np.zeros((height, width, 3), dtype=np.uint8)

    colors = [
        (0, 255, 0),
        (0, 255, 255),
        (255, 255, 0),
        (0, 165, 255),
        (255, 0, 255),
        (128, 255, 0),
        (255, 128, 0),
        (0, 128, 255),
    ]

    tooth_count = 0
    total_pixels_drawn = 0
    out_of_bounds = 0

    for tooth in tooth_data.get("teeth_data", []):
        pixel_coords = tooth.get("pixel_coordinates", [])
        color = colors[tooth_count % len(colors)]
        tooth_count += 1

        for coord in pixel_coords:
            x, y = coord[0], coord[1]
            if 0 <= x < width and 0 <= y < height:
                tooth_overlay[y, x] = color
                total_pixels_drawn += 1
            else:
                out_of_bounds += 1

    tooth_mask = np.any(tooth_overlay > 0, axis=2)
    result = roi_bgr.copy()
    blended = cv2.addWeighted(roi_bgr, 1 - alpha, tooth_overlay, alpha, 0)
    result[tooth_mask] = blended[tooth_mask]
    strong_overlay = cv2.addWeighted(result, 0.7, tooth_overlay, 0.3, 0)
    result[tooth_mask] = strong_overlay[tooth_mask]

    return result, {
        "teeth_count": tooth_count,
        "pixels_drawn": total_pixels_drawn,
        "out_of_bounds": out_of_bounds,
        "roi_shape": (height, width),
    }


def create_detailed_alignment_image(roi_img, tooth_data):
    """Create 3-panel alignment image for QA/debug."""
    height, width = roi_img.shape[:2]
    roi_normalized = np.where(roi_img > 0, 255, 0).astype(np.uint8)

    roi_colored = cv2.cvtColor(roi_normalized, cv2.COLOR_GRAY2BGR)
    caries_mask = roi_img > 0
    roi_colored[caries_mask] = [0, 0, 255]

    tooth_only = np.zeros((height, width, 3), dtype=np.uint8)
    for tooth in tooth_data.get("teeth_data", []):
        for coord in tooth.get("pixel_coordinates", []):
            x, y = coord[0], coord[1]
            if 0 <= x < width and 0 <= y < height:
                tooth_only[y, x] = [0, 255, 0]

    blended, stats = create_alignment_visualization(roi_img, tooth_data, alpha=0.6)

    tooth_mask = np.any(tooth_only > 0, axis=2)
    overlap_pixels = int(np.sum(tooth_mask & caries_mask))
    caries_pixels = int(np.sum(caries_mask))
    tooth_pixels = int(np.sum(tooth_mask))

    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(roi_colored, "ROI (Red=Caries)", (20, 60), font, 1.5, (255, 255, 255), 3)
    cv2.putText(tooth_only, "Teeth (Green)", (20, 60), font, 1.5, (255, 255, 255), 3)
    cv2.putText(blended, "ALIGNMENT CHECK", (20, 60), font, 1.5, (0, 255, 255), 3)

    stats_text = [
        f"Teeth: {stats['teeth_count']}",
        f"Tooth pixels: {tooth_pixels:,}",
        f"Caries pixels: {caries_pixels:,}",
        f"Overlap: {overlap_pixels:,}",
    ]
    y_offset = 120
    for text in stats_text:
        cv2.putText(blended, text, (20, y_offset), font, 1.0, (255, 255, 0), 2)
        y_offset += 40

    scale = 0.5
    roi_small = cv2.resize(roi_colored, None, fx=scale, fy=scale)
    tooth_small = cv2.resize(tooth_only, None, fx=scale, fy=scale)
    blended_small = cv2.resize(blended, None, fx=scale, fy=scale)
    combined = np.hstack([roi_small, tooth_small, blended_small])

    overlap_stats = {
        "overlap_pixels": overlap_pixels,
        "caries_pixels": caries_pixels,
        "tooth_pixels": tooth_pixels,
    }
    return combined, stats, overlap_stats


# =============================================================================
# Pipeline Functions for Current Project Structure
# =============================================================================

def parse_case_num_from_json(json_path: Path):
    """Extract numeric case id from filename: case_123_results.json -> 123."""
    stem = json_path.stem
    parts = stem.split("_")
    if len(parts) < 3:
        raise ValueError(f"Unexpected JSON filename format: {json_path.name}")
    return int(parts[1])


def collect_case_records(segmentation_root: Path, roi_root: Path):
    """Collect case records from Step 1 output and matching ROI paths."""
    records = []

    case_dirs = sorted(
        [p for p in segmentation_root.iterdir() if p.is_dir() and p.name.startswith("case ")],
        key=lambda p: int(p.name.replace("case ", "")),
    )

    for case_dir in case_dirs:
        json_candidates = sorted(case_dir.glob("case_*_results.json"))
        if not json_candidates:
            continue

        json_path = json_candidates[0]
        case_num = parse_case_num_from_json(json_path)
        roi_path = roi_root / f"case_{case_num}.png"

        records.append(
            {
                "case_number": case_num,
                "json_path": json_path,
                "roi_path": roi_path,
            }
        )

    return records


def process_single_case(record, output_root: Path):
    """Process one case and save both JSON + alignment image in one case folder."""
    case_num = record["case_number"]
    json_path = record["json_path"]
    roi_path = record["roi_path"]

    if not json_path.exists():
        return False, "JSON not found", None
    if not roi_path.exists():
        return False, f"ROI not found: {roi_path.name}", None

    roi_img = load_roi_image(roi_path)
    tooth_data = load_tooth_json(json_path)
    caries_results = generate_caries_mapping(roi_img, tooth_data, case_num)

    case_output_dir = output_root / f"case {case_num}"
    case_output_dir.mkdir(parents=True, exist_ok=True)

    caries_json_path = case_output_dir / f"case_{case_num}_caries_mapping.json"
    with open(caries_json_path, "w", encoding="utf-8") as f:
        json.dump(
            {
                "case_number": int(case_num),
                "teeth_caries_data": caries_results,
            },
            f,
            indent=2,
        )

    combined_img, stats, overlap_stats = create_detailed_alignment_image(roi_img, tooth_data)
    alignment_img_path = case_output_dir / f"case_{case_num}_alignment_detailed.png"
    cv2.imwrite(str(alignment_img_path), combined_img)

    teeth_with_caries = sum(1 for r in caries_results if r["has_caries"])
    msg = f"{len(caries_results)} teeth, {teeth_with_caries} with caries"

    case_stats = {
        "stats": stats,
        "overlap_stats": overlap_stats,
        "caries_results": caries_results,
    }
    return True, msg, case_stats


def run_caries_mapping_pipeline(
    segmentation_root: Path,
    roi_root: Path,
    output_root: Path,
    max_cases=None,
):
    """Run mapping pipeline and keep all outputs under one root folder."""
    output_root.mkdir(parents=True, exist_ok=True)

    records = collect_case_records(segmentation_root, roi_root)
    if not records:
        raise FileNotFoundError(
            "No case JSON files found. Check segmentation_root path and Step 1 outputs."
        )

    if max_cases is not None:
        records = records[:max_cases]
        print(f"Limiting execution to {max_cases} sample cases.")

    summary_stats = {
        "total_cases": len(records),
        "processed_cases": 0,
        "failed_cases": 0,
        "total_teeth": 0,
        "teeth_with_caries": 0,
    }
    all_caries_results = []

    print("=" * 70)
    print("Dental Caries Mapping Pipeline")
    print("=" * 70)
    print(f"Segmentation JSON source: {segmentation_root}")
    print(f"ROI source: {roi_root}")
    print(f"Output root: {output_root}")
    print("=" * 70)

    pbar = tqdm(records, desc="Processing cases", unit="case")
    for record in pbar:
        case_num = record["case_number"]
        try:
            success, msg, payload = process_single_case(record, output_root=output_root)

            if success and payload:
                case_results = payload["caries_results"]
                summary_stats["processed_cases"] += 1
                summary_stats["total_teeth"] += len(case_results)
                summary_stats["teeth_with_caries"] += sum(
                    1 for r in case_results if r["has_caries"]
                )

                for r in case_results:
                    csv_result = {k: v for k, v in r.items() if k != "caries_coordinates"}
                    all_caries_results.append(csv_result)

                pbar.set_postfix_str(f"case {case_num}: {msg}")
            else:
                summary_stats["failed_cases"] += 1
                pbar.set_postfix_str(f"case {case_num}: FAIL - {msg}")

        except Exception as e:
            summary_stats["failed_cases"] += 1
            pbar.set_postfix_str(f"case {case_num}: ERROR - {str(e)[:40]}")

    if all_caries_results:
        df = pd.DataFrame(all_caries_results)
        csv_path = output_root / "caries_mapping_results.csv"
        df.to_csv(csv_path, index=False)
        print(f"\nResults CSV saved to: {csv_path}")

        summary_df = (
            df.groupby(["case_number"]).agg(
                {
                    "tooth_id": "count",
                    "caries_pixels": "sum",
                    "has_caries": "sum",
                    "caries_percentage": "mean",
                }
            ).rename(
                columns={
                    "tooth_id": "total_teeth",
                    "has_caries": "teeth_with_caries",
                    "caries_percentage": "avg_caries_percentage",
                }
            )
        )
        summary_csv_path = output_root / "caries_summary_by_case.csv"
        summary_df.to_csv(summary_csv_path)
        print(f"Summary CSV saved to: {summary_csv_path}")

    print("\n" + "=" * 70)
    print("Processing Complete")
    print("=" * 70)
    print(f"Total cases found: {summary_stats['total_cases']}")
    print(f"Processed: {summary_stats['processed_cases']}")
    print(f"Failed: {summary_stats['failed_cases']}")
    print(f"Total teeth analyzed: {summary_stats['total_teeth']}")
    print(f"Teeth with caries: {summary_stats['teeth_with_caries']}")
    if summary_stats["total_teeth"] > 0:
        pct = summary_stats["teeth_with_caries"] / summary_stats["total_teeth"] * 100
        print(f"Caries prevalence: {pct:.2f}%")
    print("=" * 70)

    return all_caries_results, summary_stats


# =============================================================================
# Notebook Runner (Current Project Environment)
# =============================================================================

project_root = Path.cwd()

# Step 1 output folder (refactored pipeline)
segmentation_root = project_root / "segmentation+recognition-dataset"
if not segmentation_root.exists():
    raise FileNotFoundError(
        f"Segmentation output folder not found: {segmentation_root}. Run Step 1 first."
    )

# ROI folder from raw_data
roi_root = project_root.parent / "data" / "500-roi"
if not roi_root.exists():
    raise FileNotFoundError(
        f"ROI folder not found: {roi_root}."
    )

# Single output root as requested
output_root = project_root / "caries_mapping_output"

# RUN ONLY 5 SAMPLES FOR TESTING
all_caries_results, summary_stats = run_caries_mapping_pipeline(
    segmentation_root=segmentation_root,
    roi_root=roi_root,
    output_root=output_root,
    max_cases=5
)

# Uncomment the below block to run on ALL cases
# all_caries_results, summary_stats = run_caries_mapping_pipeline(
#     segmentation_root=segmentation_root,
#     roi_root=roi_root,
#     output_root=output_root,
# )
# Out:
# Limiting execution to 5 sample cases.
# ======================================================================
# Dental Caries Mapping Pipeline
# ======================================================================
# Segmentation JSON source: /Users/sukollapat/Desktop/pond_work/mahidol_work/dst_mahidol/senior_pj/coding_space/dental-caries-detection/phase2-1april/segmentation+recognition-dataset
# ROI source: /Users/sukollapat/Desktop/pond_work/mahidol_work/dst_mahidol/senior_pj/coding_space/dental-caries-detection/data/500-roi
# Output root: /Users/sukollapat/Desktop/pond_work/mahidol_work/dst_mahidol/senior_pj/coding_space/dental-caries-detection/phase2-1april/caries_mapping_output
# ======================================================================
# Processing cases:   0%|          | 0/5 [00:00<?, ?case/s]
# Results CSV saved to: /Users/sukollapat/Desktop/pond_work/mahidol_work/dst_mahidol/senior_pj/coding_space/dental-caries-detection/phase2-1april/caries_mapping_output/caries_mapping_results.csv
# Summary CSV saved to: /Users/sukollapat/Desktop/pond_work/mahidol_work/dst_mahidol/senior_pj/coding_space/dental-caries-detection/phase2-1april/caries_mapping_output/caries_summary_by_case.csv
#
# ======================================================================
# Processing Complete
# ======================================================================
# Total cases found: 5
# Processed: 5
# Failed: 0
# Total teeth analyzed: 145
# Teeth with caries: 33
# Caries prevalence: 22.76%
# ======================================================================

# %% [markdown]
# ## 3. PCA-based tooth alignment + 3-surface classification (Visualization Output)
#
# This module extends the pipeline by applying PCA-based alignment
# to each tooth and classifying caries into 3 surfaces:
# - Occlusal
# - Mesial
# - Distal
#
# It also generates visualization outputs for debugging and interpretation.
#
# Output Structure:
# - PCA_Output/case X/
#     <!-- - case_X_pca_alignment.png -->
#     - case_X_pca_results.json
#
# ## 4. Visualization of PCA-Aligned Teeth and Caries Surfaces
#
# This module provides visualization functions for each tooth after PCA alignment.
# It supports:
#
# Showing aligned tooth polygon
# Displaying Occlusal / Mesial / Distal zones
# Plotting caries pixels and centroid
# Drawing bounding box for reference
# Generating grid layout for all teeth in a case
#
# Output can be saved as .png for reporting or debugging.

# %%
# =============================================================================
# PCA & Surface Classification + Visualization
# =============================================================================

import os
import json
import numpy as np
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from pathlib import Path

# =============================================================================
# CONFIG
# =============================================================================
# SEG_DIR = "segmentation+recognition-dataset"
# CARIES_DIR = "caries_mapping_output"
SEG_DIR = r"C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition"
CARIES_DIR = r"C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output"
OUT_DIR = "PCA_Output"

os.makedirs(OUT_DIR, exist_ok=True)

OCCLUSAL_RATIO = 0.30
SIDE_RATIO = 0.25

SURFACE_COLORS = {
    "Occlusal": "#E74C3C",
    "Mesial": "#3498DB",
    "Distal": "#3498DB",
    "Other": "#2ECC71",
    -1: "#95A5A6"
}

# =============================================================================
# HELPERS
# =============================================================================
def is_upper_jaw(tid):
    quadrant = int(str(tid)[0])
    return quadrant in [1, 2]


def is_left_side(tid):
    quadrant = int(str(tid)[0])
    return quadrant in [2, 3]


def load_seg(case_id):
    path = os.path.join(
        SEG_DIR,
        f"case {case_id}",
        f"case_{case_id}_results.json"
    )

    if not os.path.exists(path):
        print(f"[ERROR] SEG missing: {path}")
        return None

    with open(path, "r") as f:
        return json.load(f)


def load_caries(case_id):
    path = os.path.join(
        CARIES_DIR,
        f"case {case_id}",
        f"case_{case_id}_caries_mapping.json"
    )

    if not os.path.exists(path):
        print(f"[ERROR] CARIES missing: {path}")
        return None

    with open(path, "r") as f:
        return json.load(f)


def build_seg_map(seg_data):
    mapping = {}

    for tooth in seg_data.get("teeth_data", []):
        tid = str(tooth["tooth_id"])
        mapping[tid] = tooth.get("pixel_coordinates", [])

    return mapping


def get_caries_list(caries_data):
    return caries_data.get("teeth_caries_data", [])


def compute_centroid(points):
    pts = np.array(points, dtype=np.float64)
    return np.mean(pts[:, 0]), np.mean(pts[:, 1])


def get_bbox(points):
    pts = np.array(points, dtype=np.float64)

    x_min, y_min = np.min(pts, axis=0)
    x_max, y_max = np.max(pts, axis=0)

    return x_min, y_min, x_max - x_min, y_max - y_min


# =============================================================================
# PCA
# =============================================================================
def perform_pca(points, tooth_id):
    pts = np.array(points, dtype=np.float64)

    mean = np.mean(pts, axis=0)
    centered = pts - mean

    cov = np.cov(centered, rowvar=False)
    eigenvalues, eigenvectors = np.linalg.eigh(cov)

    idx = np.argsort(eigenvalues)[::-1]
    major_axis = eigenvectors[:, idx[0]]

    major_axis = major_axis / np.linalg.norm(major_axis)

    # ---- Fix axis direction ----
    if is_upper_jaw(tooth_id):
        if major_axis[1] < 0:
            major_axis = -major_axis
    else:
        if major_axis[1] > 0:
            major_axis = -major_axis

    # ---- IMPORTANT: rotate to vertical ----
    major_angle = np.arctan2(major_axis[1], major_axis[0])

    rotation_angle = (np.pi / 2) - major_angle

    return mean, rotation_angle


def rotate(points, center, angle):
    pts = np.array(points, dtype=np.float64)

    c = np.cos(angle)
    s = np.sin(angle)

    pts_centered = pts - center

    rot_matrix = np.array([
        [c, -s],
        [s, c]
    ])

    rotated = np.dot(pts_centered, rot_matrix.T)

    return rotated + center


# =============================================================================
# CLASSIFICATION
# =============================================================================
def classify_surface_full(tid, tooth_pts, caries_pts):
    center, angle = perform_pca(tooth_pts, tid)

    tooth_rot = rotate(tooth_pts, center, angle)
    caries_rot = rotate(caries_pts, center, angle)

    x, y, w, h = get_bbox(tooth_rot)
    cx, cy = compute_centroid(tooth_rot) # Use tooth centroid for relative position

    rel_x = (cx - x) / w
    rel_y = (cy - y) / h

    upper = is_upper_jaw(tid)
    left_side = is_left_side(tid)

    # ---- Occlusal ----
    if upper:
        if rel_y >= (1 - OCCLUSAL_RATIO):
            return "Occlusal", float(np.degrees(angle))
    else:
        if rel_y <= OCCLUSAL_RATIO:
            return "Occlusal", float(np.degrees(angle))

    # ---- Mesial / Distal ----
    if rel_x <= SIDE_RATIO:
        if left_side:
            return "Distal", float(np.degrees(angle))
        else:
            return "Mesial", float(np.degrees(angle))

    if rel_x >= (1 - SIDE_RATIO):
        if left_side:
            return "Mesial", float(np.degrees(angle))
        else:
            return "Distal", float(np.degrees(angle))

    return "Other", float(np.degrees(angle))


def compute_caries_stats(caries_pts, tooth_pts):
    caries_pixels = len(caries_pts)
    tooth_pixels = len(tooth_pts)

    if tooth_pixels == 0:
        return 0, 0

    percentage = (caries_pixels / tooth_pixels) * 100

    return caries_pixels, percentage


# =============================================================================
# VISUALIZATION
# =============================================================================
def visualize_tooth_with_zones(
    tooth_pts,
    caries_pts,
    tooth_id,
    classification,
    save_path=None
):
    tooth_pts = np.array(tooth_pts, dtype=np.float64)
    caries_pts = np.array(caries_pts, dtype=np.float64)

    x, y = np.min(tooth_pts, axis=0)
    w, h = np.ptp(tooth_pts, axis=0)

    fig, ax = plt.subplots(figsize=(6, 6))

    # ---- Zones ----
    if is_upper_jaw(tooth_id):
        occ_start = y + h * (1 - OCCLUSAL_RATIO)
        occ_end = y + h
    else:
        occ_start = y
        occ_end = y + h * OCCLUSAL_RATIO

    left_bound = x + w * SIDE_RATIO
    right_bound = x + w * (1 - SIDE_RATIO)

    ax.fill(
        [x, x+w, x+w, x],
        [occ_start, occ_start, occ_end, occ_end],
        alpha=0.2,
        color=SURFACE_COLORS["Occlusal"]
    )

    ax.fill(
        [x, left_bound, left_bound, x],
        [y, y, y+h, y+h],
        alpha=0.2,
        color=SURFACE_COLORS["Mesial"]
    )

    ax.fill(
        [right_bound, x+w, x+w, right_bound],
        [y, y, y+h, y+h],
        alpha=0.2,
        color=SURFACE_COLORS["Distal"]
    )

    # ---- Tooth ----
    ax.scatter(
        tooth_pts[:, 0],
        tooth_pts[:, 1],
        c="gray",
        s=3,
        alpha=0.5
    )

    # ---- Caries ----
    if len(caries_pts) > 0:
        ax.scatter(
            caries_pts[:, 0],
            caries_pts[:, 1],
            c=SURFACE_COLORS[classification],
            s=10
        )

    cx, cy = compute_centroid(caries_pts)

    ax.plot(
        cx,
        cy,
        "*",
        markersize=15
    )

    rect = Rectangle(
        (x, y),
        w,
        h,
        fill=False,
        linestyle="--",
        linewidth=1
    )

    ax.add_patch(rect)

    ax.set_title(f"Tooth {tooth_id} - {classification}")
    ax.set_aspect("equal")
    ax.invert_yaxis()
    ax.axis("off")

    if save_path:
        Path(save_path).parent.mkdir(parents=True, exist_ok=True)
        fig.savefig(save_path, dpi=150, bbox_inches="tight")
        plt.close(fig)

    return fig


# =============================================================================
# PROCESS CASE
# =============================================================================
def process_case(case_id):
    print(f"\n=== CASE {case_id} ===")

    seg_data = load_seg(case_id)
    caries_data = load_caries(case_id)

    if seg_data is None or caries_data is None:
        return

    seg_map = build_seg_map(seg_data)
    caries_list = get_caries_list(caries_data)

    results = {
        "case_number": case_id,
        "teeth_data": []
    }

    for tooth in caries_list:
        tid = str(tooth["tooth_id"])

        caries_pts = tooth.get("caries_coordinates", [])
        tooth_pts = seg_map.get(tid, [])

        if len(caries_pts) == 0 or len(tooth_pts) < 10:
            continue

        surface, angle = classify_surface_full(
            tid,
            tooth_pts,
            caries_pts
        )

        pixels, percentage = compute_caries_stats(
            caries_pts,
            tooth_pts
        )

        results["teeth_data"].append({
            "tooth_id": tid,
            "has_caries": True,
            "confidence": tooth.get("confidence", 0),
            "caries_position_detail": surface,
            "rotation_angle": round(angle, 2),
            "tooth_coordinates": tooth_pts,
            "caries_coordinates": caries_pts,
            "caries_pixels": pixels,
            "caries_percentage": round(percentage, 4)
        })

    case_dir = os.path.join(OUT_DIR, f"case_{case_id}")
    os.makedirs(case_dir, exist_ok=True)

    json_path = os.path.join(
        case_dir,
        f"case_{case_id}.json"
    )

    with open(json_path, "w") as f:
        json.dump(results, f, indent=4)

    print(f"[DONE] saved → {json_path}")


def process_case_visual(case_id):
    case_dir = Path(OUT_DIR) / f"case_{case_id}"

    json_path = case_dir / f"case_{case_id}.json"

    if not json_path.exists():
        print(f"[SKIP] Case {case_id}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    for tooth in data["teeth_data"]:
        tid = tooth["tooth_id"]

        tooth_pts = tooth["tooth_coordinates"]
        caries_pts = tooth["caries_coordinates"]

        center, angle = perform_pca(tooth_pts, tid)

        tooth_rot = rotate(tooth_pts, center, angle)
        caries_rot = rotate(caries_pts, center, angle)

        tooth_dir = case_dir / f"tooth_{tid}"
        tooth_dir.mkdir(parents=True, exist_ok=True)

        save_path = tooth_dir / f"tooth_{tid}_visual.png"

        visualize_tooth_with_zones(
            tooth_rot,
            caries_rot,
            tid,
            tooth["caries_position_detail"],
            save_path=save_path
        )

    print(f"[DONE] visuals → Case {case_id}")


# =============================================================================
# RUN ALL
# =============================================================================
# Uncomment below to run ALL cases
for cid in range(1, 501):
    process_case(cid)
    process_case_visual(cid)
# Out:
# === CASE 1 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 1/case_1_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 1/case_1_caries_mapping.json
# [SKIP] Case 1
#
# === CASE 2 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 2/case_2_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 2/case_2_caries_mapping.json
# [SKIP] Case 2
#
# === CASE 3 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 3/case_3_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 3/case_3_caries_mapping.json
# [SKIP] Case 3
#
# === CASE 4 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 4/case_4_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 4/case_4_caries_mapping.json
# [SKIP] Case 4
#
# === CASE 5 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 5/case_5_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 5/case_5_caries_mapping.json
# [SKIP] Case 5
#
# === CASE 6 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 6/case_6_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 6/case_6_caries_mapping.json
# [SKIP] Case 6
#
# === CASE 7 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 7/case_7_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 7/case_7_caries_mapping.json
# [SKIP] Case 7
#
# === CASE 8 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 8/case_8_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 8/case_8_caries_mapping.json
# [SKIP] Case 8
#
# === CASE 9 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 9/case_9_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 9/case_9_caries_mapping.json
# [SKIP] Case 9
#
# === CASE 10 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 10/case_10_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 10/case_10_caries_mapping.json
# [SKIP] Case 10
#
# === CASE 11 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 11/case_11_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 11/case_11_caries_mapping.json
# [SKIP] Case 11
#
# === CASE 12 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 12/case_12_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 12/case_12_caries_mapping.json
# [SKIP] Case 12
#
# === CASE 13 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 13/case_13_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 13/case_13_caries_mapping.json
# [SKIP] Case 13
#
# === CASE 14 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 14/case_14_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 14/case_14_caries_mapping.json
# [SKIP] Case 14
#
# === CASE 15 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 15/case_15_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 15/case_15_caries_mapping.json
# [SKIP] Case 15
#
# === CASE 16 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 16/case_16_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 16/case_16_caries_mapping.json
# [SKIP] Case 16
#
# === CASE 17 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 17/case_17_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 17/case_17_caries_mapping.json
# [SKIP] Case 17
#
# === CASE 18 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 18/case_18_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 18/case_18_caries_mapping.json
# [SKIP] Case 18
#
# === CASE 19 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 19/case_19_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 19/case_19_caries_mapping.json
# [SKIP] Case 19
#
# === CASE 20 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 20/case_20_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 20/case_20_caries_mapping.json
# [SKIP] Case 20
#
# === CASE 21 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 21/case_21_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 21/case_21_caries_mapping.json
# [SKIP] Case 21
#
# === CASE 22 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 22/case_22_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 22/case_22_caries_mapping.json
# [SKIP] Case 22
#
# === CASE 23 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 23/case_23_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 23/case_23_caries_mapping.json
# [SKIP] Case 23
#
# === CASE 24 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 24/case_24_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 24/case_24_caries_mapping.json
# [SKIP] Case 24
#
# === CASE 25 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 25/case_25_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 25/case_25_caries_mapping.json
# [SKIP] Case 25
#
# === CASE 26 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 26/case_26_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 26/case_26_caries_mapping.json
# [SKIP] Case 26
#
# === CASE 27 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 27/case_27_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 27/case_27_caries_mapping.json
# [SKIP] Case 27
#
# === CASE 28 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 28/case_28_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 28/case_28_caries_mapping.json
# [SKIP] Case 28
#
# === CASE 29 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 29/case_29_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 29/case_29_caries_mapping.json
# [SKIP] Case 29
#
# === CASE 30 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 30/case_30_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 30/case_30_caries_mapping.json
# [SKIP] Case 30
#
# === CASE 31 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 31/case_31_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 31/case_31_caries_mapping.json
# [SKIP] Case 31
#
# === CASE 32 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 32/case_32_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 32/case_32_caries_mapping.json
# [SKIP] Case 32
#
# === CASE 33 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 33/case_33_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 33/case_33_caries_mapping.json
# [SKIP] Case 33
#
# === CASE 34 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 34/case_34_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 34/case_34_caries_mapping.json
# [SKIP] Case 34
#
# === CASE 35 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 35/case_35_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 35/case_35_caries_mapping.json
# [SKIP] Case 35
#
# === CASE 36 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 36/case_36_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 36/case_36_caries_mapping.json
# [SKIP] Case 36
#
# === CASE 37 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 37/case_37_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 37/case_37_caries_mapping.json
# [SKIP] Case 37
#
# === CASE 38 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 38/case_38_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 38/case_38_caries_mapping.json
# [SKIP] Case 38
#
# === CASE 39 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 39/case_39_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 39/case_39_caries_mapping.json
# [SKIP] Case 39
#
# === CASE 40 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 40/case_40_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 40/case_40_caries_mapping.json
# [SKIP] Case 40
#
# === CASE 41 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 41/case_41_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 41/case_41_caries_mapping.json
# [SKIP] Case 41
#
# === CASE 42 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 42/case_42_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 42/case_42_caries_mapping.json
# [SKIP] Case 42
#
# === CASE 43 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 43/case_43_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 43/case_43_caries_mapping.json
# [SKIP] Case 43
#
# === CASE 44 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 44/case_44_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 44/case_44_caries_mapping.json
# [SKIP] Case 44
#
# === CASE 45 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 45/case_45_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 45/case_45_caries_mapping.json
# [SKIP] Case 45
#
# === CASE 46 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 46/case_46_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 46/case_46_caries_mapping.json
# [SKIP] Case 46
#
# === CASE 47 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 47/case_47_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 47/case_47_caries_mapping.json
# [SKIP] Case 47
#
# === CASE 48 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 48/case_48_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 48/case_48_caries_mapping.json
# [SKIP] Case 48
#
# === CASE 49 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 49/case_49_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 49/case_49_caries_mapping.json
# [SKIP] Case 49
#
# === CASE 50 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 50/case_50_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 50/case_50_caries_mapping.json
# [SKIP] Case 50
#
# === CASE 51 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 51/case_51_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 51/case_51_caries_mapping.json
# [SKIP] Case 51
#
# === CASE 52 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 52/case_52_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 52/case_52_caries_mapping.json
# [SKIP] Case 52
#
# === CASE 53 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 53/case_53_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 53/case_53_caries_mapping.json
# [SKIP] Case 53
#
# === CASE 54 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 54/case_54_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 54/case_54_caries_mapping.json
# [SKIP] Case 54
#
# === CASE 55 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 55/case_55_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 55/case_55_caries_mapping.json
# [SKIP] Case 55
#
# === CASE 56 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 56/case_56_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 56/case_56_caries_mapping.json
# [SKIP] Case 56
#
# === CASE 57 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 57/case_57_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 57/case_57_caries_mapping.json
# [SKIP] Case 57
#
# === CASE 58 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 58/case_58_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 58/case_58_caries_mapping.json
# [SKIP] Case 58
#
# === CASE 59 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 59/case_59_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 59/case_59_caries_mapping.json
# [SKIP] Case 59
#
# === CASE 60 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 60/case_60_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 60/case_60_caries_mapping.json
# [SKIP] Case 60
#
# === CASE 61 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 61/case_61_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 61/case_61_caries_mapping.json
# [SKIP] Case 61
#
# === CASE 62 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 62/case_62_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 62/case_62_caries_mapping.json
# [SKIP] Case 62
#
# === CASE 63 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 63/case_63_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 63/case_63_caries_mapping.json
# [SKIP] Case 63
#
# === CASE 64 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 64/case_64_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 64/case_64_caries_mapping.json
# [SKIP] Case 64
#
# === CASE 65 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 65/case_65_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 65/case_65_caries_mapping.json
# [SKIP] Case 65
#
# === CASE 66 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 66/case_66_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 66/case_66_caries_mapping.json
# [SKIP] Case 66
#
# === CASE 67 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 67/case_67_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 67/case_67_caries_mapping.json
# [SKIP] Case 67
#
# === CASE 68 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 68/case_68_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 68/case_68_caries_mapping.json
# [SKIP] Case 68
#
# === CASE 69 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 69/case_69_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 69/case_69_caries_mapping.json
# [SKIP] Case 69
#
# === CASE 70 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 70/case_70_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 70/case_70_caries_mapping.json
# [SKIP] Case 70
#
# === CASE 71 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 71/case_71_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 71/case_71_caries_mapping.json
# [SKIP] Case 71
#
# === CASE 72 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 72/case_72_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 72/case_72_caries_mapping.json
# [SKIP] Case 72
#
# === CASE 73 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 73/case_73_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 73/case_73_caries_mapping.json
# [SKIP] Case 73
#
# === CASE 74 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 74/case_74_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 74/case_74_caries_mapping.json
# [SKIP] Case 74
#
# === CASE 75 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 75/case_75_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 75/case_75_caries_mapping.json
# [SKIP] Case 75
#
# === CASE 76 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 76/case_76_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 76/case_76_caries_mapping.json
# [SKIP] Case 76
#
# === CASE 77 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 77/case_77_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 77/case_77_caries_mapping.json
# [SKIP] Case 77
#
# === CASE 78 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 78/case_78_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 78/case_78_caries_mapping.json
# [SKIP] Case 78
#
# === CASE 79 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 79/case_79_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 79/case_79_caries_mapping.json
# [SKIP] Case 79
#
# === CASE 80 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 80/case_80_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 80/case_80_caries_mapping.json
# [SKIP] Case 80
#
# === CASE 81 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 81/case_81_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 81/case_81_caries_mapping.json
# [SKIP] Case 81
#
# === CASE 82 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 82/case_82_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 82/case_82_caries_mapping.json
# [SKIP] Case 82
#
# === CASE 83 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 83/case_83_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 83/case_83_caries_mapping.json
# [SKIP] Case 83
#
# === CASE 84 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 84/case_84_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 84/case_84_caries_mapping.json
# [SKIP] Case 84
#
# === CASE 85 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 85/case_85_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 85/case_85_caries_mapping.json
# [SKIP] Case 85
#
# === CASE 86 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 86/case_86_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 86/case_86_caries_mapping.json
# [SKIP] Case 86
#
# === CASE 87 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 87/case_87_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 87/case_87_caries_mapping.json
# [SKIP] Case 87
#
# === CASE 88 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 88/case_88_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 88/case_88_caries_mapping.json
# [SKIP] Case 88
#
# === CASE 89 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 89/case_89_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 89/case_89_caries_mapping.json
# [SKIP] Case 89
#
# === CASE 90 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 90/case_90_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 90/case_90_caries_mapping.json
# [SKIP] Case 90
#
# === CASE 91 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 91/case_91_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 91/case_91_caries_mapping.json
# [SKIP] Case 91
#
# === CASE 92 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 92/case_92_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 92/case_92_caries_mapping.json
# [SKIP] Case 92
#
# === CASE 93 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 93/case_93_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 93/case_93_caries_mapping.json
# [SKIP] Case 93
#
# === CASE 94 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 94/case_94_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 94/case_94_caries_mapping.json
# [SKIP] Case 94
#
# === CASE 95 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 95/case_95_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 95/case_95_caries_mapping.json
# [SKIP] Case 95
#
# === CASE 96 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 96/case_96_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 96/case_96_caries_mapping.json
# [SKIP] Case 96
#
# === CASE 97 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 97/case_97_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 97/case_97_caries_mapping.json
# [SKIP] Case 97
#
# === CASE 98 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 98/case_98_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 98/case_98_caries_mapping.json
# [SKIP] Case 98
#
# === CASE 99 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 99/case_99_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 99/case_99_caries_mapping.json
# [SKIP] Case 99
#
# === CASE 100 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 100/case_100_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 100/case_100_caries_mapping.json
# [SKIP] Case 100
#
# === CASE 101 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 101/case_101_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 101/case_101_caries_mapping.json
# [SKIP] Case 101
#
# === CASE 102 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 102/case_102_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 102/case_102_caries_mapping.json
# [SKIP] Case 102
#
# === CASE 103 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 103/case_103_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 103/case_103_caries_mapping.json
# [SKIP] Case 103
#
# === CASE 104 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 104/case_104_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 104/case_104_caries_mapping.json
# [SKIP] Case 104
#
# === CASE 105 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 105/case_105_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 105/case_105_caries_mapping.json
# [SKIP] Case 105
#
# === CASE 106 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 106/case_106_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 106/case_106_caries_mapping.json
# [SKIP] Case 106
#
# === CASE 107 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 107/case_107_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 107/case_107_caries_mapping.json
# [SKIP] Case 107
#
# === CASE 108 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 108/case_108_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 108/case_108_caries_mapping.json
# [SKIP] Case 108
#
# === CASE 109 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 109/case_109_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 109/case_109_caries_mapping.json
# [SKIP] Case 109
#
# === CASE 110 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 110/case_110_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 110/case_110_caries_mapping.json
# [SKIP] Case 110
#
# === CASE 111 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 111/case_111_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 111/case_111_caries_mapping.json
# [SKIP] Case 111
#
# === CASE 112 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 112/case_112_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 112/case_112_caries_mapping.json
# [SKIP] Case 112
#
# === CASE 113 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 113/case_113_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 113/case_113_caries_mapping.json
# [SKIP] Case 113
#
# === CASE 114 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 114/case_114_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 114/case_114_caries_mapping.json
# [SKIP] Case 114
#
# === CASE 115 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 115/case_115_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 115/case_115_caries_mapping.json
# [SKIP] Case 115
#
# === CASE 116 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 116/case_116_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 116/case_116_caries_mapping.json
# [SKIP] Case 116
#
# === CASE 117 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 117/case_117_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 117/case_117_caries_mapping.json
# [SKIP] Case 117
#
# === CASE 118 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 118/case_118_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 118/case_118_caries_mapping.json
# [SKIP] Case 118
#
# === CASE 119 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 119/case_119_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 119/case_119_caries_mapping.json
# [SKIP] Case 119
#
# === CASE 120 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 120/case_120_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 120/case_120_caries_mapping.json
# [SKIP] Case 120
#
# === CASE 121 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 121/case_121_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 121/case_121_caries_mapping.json
# [SKIP] Case 121
#
# === CASE 122 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 122/case_122_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 122/case_122_caries_mapping.json
# [SKIP] Case 122
#
# === CASE 123 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 123/case_123_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 123/case_123_caries_mapping.json
# [SKIP] Case 123
#
# === CASE 124 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 124/case_124_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 124/case_124_caries_mapping.json
# [SKIP] Case 124
#
# === CASE 125 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 125/case_125_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 125/case_125_caries_mapping.json
# [SKIP] Case 125
#
# === CASE 126 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 126/case_126_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 126/case_126_caries_mapping.json
# [SKIP] Case 126
#
# === CASE 127 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 127/case_127_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 127/case_127_caries_mapping.json
# [SKIP] Case 127
#
# === CASE 128 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 128/case_128_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 128/case_128_caries_mapping.json
# [SKIP] Case 128
#
# === CASE 129 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 129/case_129_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 129/case_129_caries_mapping.json
# [SKIP] Case 129
#
# === CASE 130 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 130/case_130_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 130/case_130_caries_mapping.json
# [SKIP] Case 130
#
# === CASE 131 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 131/case_131_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 131/case_131_caries_mapping.json
# [SKIP] Case 131
#
# === CASE 132 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 132/case_132_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 132/case_132_caries_mapping.json
# [SKIP] Case 132
#
# === CASE 133 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 133/case_133_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 133/case_133_caries_mapping.json
# [SKIP] Case 133
#
# === CASE 134 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 134/case_134_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 134/case_134_caries_mapping.json
# [SKIP] Case 134
#
# === CASE 135 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 135/case_135_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 135/case_135_caries_mapping.json
# [SKIP] Case 135
#
# === CASE 136 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 136/case_136_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 136/case_136_caries_mapping.json
# [SKIP] Case 136
#
# === CASE 137 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 137/case_137_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 137/case_137_caries_mapping.json
# [SKIP] Case 137
#
# === CASE 138 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 138/case_138_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 138/case_138_caries_mapping.json
# [SKIP] Case 138
#
# === CASE 139 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 139/case_139_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 139/case_139_caries_mapping.json
# [SKIP] Case 139
#
# === CASE 140 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 140/case_140_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 140/case_140_caries_mapping.json
# [SKIP] Case 140
#
# === CASE 141 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 141/case_141_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 141/case_141_caries_mapping.json
# [SKIP] Case 141
#
# === CASE 142 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 142/case_142_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 142/case_142_caries_mapping.json
# [SKIP] Case 142
#
# === CASE 143 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 143/case_143_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 143/case_143_caries_mapping.json
# [SKIP] Case 143
#
# === CASE 144 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 144/case_144_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 144/case_144_caries_mapping.json
# [SKIP] Case 144
#
# === CASE 145 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 145/case_145_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 145/case_145_caries_mapping.json
# [SKIP] Case 145
#
# === CASE 146 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 146/case_146_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 146/case_146_caries_mapping.json
# [SKIP] Case 146
#
# === CASE 147 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 147/case_147_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 147/case_147_caries_mapping.json
# [SKIP] Case 147
#
# === CASE 148 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 148/case_148_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 148/case_148_caries_mapping.json
# [SKIP] Case 148
#
# === CASE 149 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 149/case_149_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 149/case_149_caries_mapping.json
# [SKIP] Case 149
#
# === CASE 150 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 150/case_150_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 150/case_150_caries_mapping.json
# [SKIP] Case 150
#
# === CASE 151 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 151/case_151_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 151/case_151_caries_mapping.json
# [SKIP] Case 151
#
# === CASE 152 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 152/case_152_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 152/case_152_caries_mapping.json
# [SKIP] Case 152
#
# === CASE 153 ===
# ...
# [SKIP] Case 450
#
# === CASE 451 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 451/case_451_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 451/case_451_caries_mapping.json
# [SKIP] Case 451
#
# === CASE 452 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 452/case_452_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 452/case_452_caries_mapping.json
# [SKIP] Case 452
#
# === CASE 453 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 453/case_453_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 453/case_453_caries_mapping.json
# [SKIP] Case 453
#
# === CASE 454 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 454/case_454_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 454/case_454_caries_mapping.json
# [SKIP] Case 454
#
# === CASE 455 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 455/case_455_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 455/case_455_caries_mapping.json
# [SKIP] Case 455
#
# === CASE 456 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 456/case_456_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 456/case_456_caries_mapping.json
# [SKIP] Case 456
#
# === CASE 457 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 457/case_457_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 457/case_457_caries_mapping.json
# [SKIP] Case 457
#
# === CASE 458 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 458/case_458_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 458/case_458_caries_mapping.json
# [SKIP] Case 458
#
# === CASE 459 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 459/case_459_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 459/case_459_caries_mapping.json
# [SKIP] Case 459
#
# === CASE 460 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 460/case_460_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 460/case_460_caries_mapping.json
# [SKIP] Case 460
#
# === CASE 461 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 461/case_461_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 461/case_461_caries_mapping.json
# [SKIP] Case 461
#
# === CASE 462 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 462/case_462_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 462/case_462_caries_mapping.json
# [SKIP] Case 462
#
# === CASE 463 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 463/case_463_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 463/case_463_caries_mapping.json
# [SKIP] Case 463
#
# === CASE 464 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 464/case_464_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 464/case_464_caries_mapping.json
# [SKIP] Case 464
#
# === CASE 465 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 465/case_465_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 465/case_465_caries_mapping.json
# [SKIP] Case 465
#
# === CASE 466 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 466/case_466_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 466/case_466_caries_mapping.json
# [SKIP] Case 466
#
# === CASE 467 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 467/case_467_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 467/case_467_caries_mapping.json
# [SKIP] Case 467
#
# === CASE 468 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 468/case_468_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 468/case_468_caries_mapping.json
# [SKIP] Case 468
#
# === CASE 469 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 469/case_469_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 469/case_469_caries_mapping.json
# [SKIP] Case 469
#
# === CASE 470 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 470/case_470_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 470/case_470_caries_mapping.json
# [SKIP] Case 470
#
# === CASE 471 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 471/case_471_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 471/case_471_caries_mapping.json
# [SKIP] Case 471
#
# === CASE 472 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 472/case_472_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 472/case_472_caries_mapping.json
# [SKIP] Case 472
#
# === CASE 473 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 473/case_473_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 473/case_473_caries_mapping.json
# [SKIP] Case 473
#
# === CASE 474 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 474/case_474_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 474/case_474_caries_mapping.json
# [SKIP] Case 474
#
# === CASE 475 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 475/case_475_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 475/case_475_caries_mapping.json
# [SKIP] Case 475
#
# === CASE 476 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 476/case_476_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 476/case_476_caries_mapping.json
# [SKIP] Case 476
#
# === CASE 477 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 477/case_477_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 477/case_477_caries_mapping.json
# [SKIP] Case 477
#
# === CASE 478 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 478/case_478_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 478/case_478_caries_mapping.json
# [SKIP] Case 478
#
# === CASE 479 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 479/case_479_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 479/case_479_caries_mapping.json
# [SKIP] Case 479
#
# === CASE 480 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 480/case_480_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 480/case_480_caries_mapping.json
# [SKIP] Case 480
#
# === CASE 481 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 481/case_481_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 481/case_481_caries_mapping.json
# [SKIP] Case 481
#
# === CASE 482 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 482/case_482_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 482/case_482_caries_mapping.json
# [SKIP] Case 482
#
# === CASE 483 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 483/case_483_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 483/case_483_caries_mapping.json
# [SKIP] Case 483
#
# === CASE 484 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 484/case_484_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 484/case_484_caries_mapping.json
# [SKIP] Case 484
#
# === CASE 485 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 485/case_485_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 485/case_485_caries_mapping.json
# [SKIP] Case 485
#
# === CASE 486 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 486/case_486_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 486/case_486_caries_mapping.json
# [SKIP] Case 486
#
# === CASE 487 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 487/case_487_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 487/case_487_caries_mapping.json
# [SKIP] Case 487
#
# === CASE 488 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 488/case_488_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 488/case_488_caries_mapping.json
# [SKIP] Case 488
#
# === CASE 489 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 489/case_489_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 489/case_489_caries_mapping.json
# [SKIP] Case 489
#
# === CASE 490 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 490/case_490_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 490/case_490_caries_mapping.json
# [SKIP] Case 490
#
# === CASE 491 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 491/case_491_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 491/case_491_caries_mapping.json
# [SKIP] Case 491
#
# === CASE 492 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 492/case_492_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 492/case_492_caries_mapping.json
# [SKIP] Case 492
#
# === CASE 493 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 493/case_493_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 493/case_493_caries_mapping.json
# [SKIP] Case 493
#
# === CASE 494 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 494/case_494_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 494/case_494_caries_mapping.json
# [SKIP] Case 494
#
# === CASE 495 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 495/case_495_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 495/case_495_caries_mapping.json
# [SKIP] Case 495
#
# === CASE 496 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 496/case_496_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 496/case_496_caries_mapping.json
# [SKIP] Case 496
#
# === CASE 497 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 497/case_497_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 497/case_497_caries_mapping.json
# [SKIP] Case 497
#
# === CASE 498 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 498/case_498_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 498/case_498_caries_mapping.json
# [SKIP] Case 498
#
# === CASE 499 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 499/case_499_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 499/case_499_caries_mapping.json
# [SKIP] Case 499
#
# === CASE 500 ===
# [ERROR] SEG missing: C:\Users\jaopi\Desktop\SP\week2-Tooth Detection & Segmentation\500-segmentation+recognition/case 500/case_500_results.json
# [ERROR] CARIES missing: C:\Users\jaopi\Desktop\SP\week3-Caries-to-Tooth Mapping\dental_analysis_output/case 500/case_500_caries_mapping.json
# [SKIP] Case 500

# %% [markdown]
# ## XML Parse Coverage
# เช็คว่า xml ที่แปลงมาเป็น GT ใช้ได้จริง

# %%
from pathlib import Path
import xml.etree.ElementTree as ET

# =========================================================
# Namespace
# =========================================================
AIM_NS = "gme://caCORE.caCORE/4.4/edu.northwestern.radiology.AIM"
ISO_NS = "uri:iso.org:21090"
NS = {"aim": AIM_NS, "iso": ISO_NS}

# =========================================================
# Surface map
# =========================================================
SNODENT_SURFACE_MAP = {
    "144414D": "Occlusal",
    "146014D": "Distal",
    "145374D": "Mesial",
    "144474D": "Occlusal",
    "146074D": "Distal",
    "145434D": "Mesial",
}

DISPLAY_NAME_TO_SURFACE = {
    "Occlusal surface": "Occlusal",
    "Occlusal Surface": "Occlusal",
    "Distal Surface": "Distal",
    "Distal surface": "Distal",
    "Mesial Surface": "Mesial",
    "Mesial surface": "Mesial",
}

# =============================================================================
# SNODENT Code → FDI Tooth ID Mapping
# =============================================================================
# Key = SNODENT code from XML <ImagingPhysicalEntityCharacteristic>
# Value = FDI two-digit tooth number
#
# FDI Quadrants:
#   Q1 (11–18): Upper Right    Q2 (21–28): Upper Left
#   Q3 (31–38): Lower Left     Q4 (41–48): Lower Right

# =========================================================
# Tooth fallback map
# =========================================================
SNODENT_TO_FDI = {
    # ===================== UPPER RIGHT (Quadrant 1) =====================
    "161006D": "11",  # Permanent upper right central incisor tooth
    "160842D": "12",  # Permanent upper right lateral incisor tooth
    "160288D": "13",  # Permanent upper right canine tooth
    "161286D": "14",  # Permanent upper right first premolar tooth
    "160450D": "15",  # Permanent upper right second premolar tooth
    "160770D": "16",  # Permanent upper right first molar tooth       # NOTE: also used for lower in some datasets
    "161204D": "17",  # Permanent upper right second molar tooth
    "160618D": "18",  # Permanent upper right third molar tooth

    # ===================== UPPER LEFT (Quadrant 2) =====================
    "160194D": "21",  # Permanent upper left central incisor tooth
    "160132D": "22",  # Permanent upper left lateral incisor tooth
    "160506D": "23",  # Permanent upper left canine tooth
    "161340D": "24",  # Permanent upper left first premolar tooth
    "160682D": "25",  # Permanent upper left second premolar tooth
    "161074D": "26",  # Permanent upper left first molar tooth
    "160386D": "27",  # Permanent upper left second molar tooth
    "160922D": "28",  # Permanent upper left third molar tooth

    # ===================== LOWER LEFT (Quadrant 3) =====================
    "161136D": "31",  # Permanent lower left central incisor tooth
    "160556D": "32",  # Permanent lower left lateral incisor tooth
    "160068D": "33",  # Permanent lower left canine tooth
    "160326D": "34",  # Permanent lower left first premolar tooth
    "161248D": "35",  # Permanent lower left second premolar tooth
    "160730D": "36",  # Permanent lower left first molar tooth
    "161166D": "37",  # Permanent lower left second molar tooth
    "160580D": "38",  # Permanent lower left third molar tooth

    # ===================== LOWER RIGHT (Quadrant 4) =====================
    "160964D": "41",  # Permanent lower right central incisor tooth
    "160350D": "42",  # Permanent lower right lateral incisor tooth
    "160894D": "43",  # Permanent lower right canine tooth
    "160230D": "44",  # Permanent lower right first premolar tooth
    "161412D": "45",  # Permanent lower right second premolar tooth
    "160770D": "46",  # Permanent lower right first molar tooth       # CAUTION: shared code
    "161102D": "47",  # Permanent lower right second molar tooth
    "160488D": "48",  # Permanent lower right third molar tooth
}

# =========================================================
# Helpers
# =========================================================
def _get_display_name(element):
    dn = element.find("iso:displayName", NS)
    if dn is not None:
        return dn.get("value", "")
    return ""

def snodent_display_to_fdi(display_name):

    dn = display_name.lower()

    if "upper" in dn and "right" in dn:
        quadrant = 1
    elif "upper" in dn and "left" in dn:
        quadrant = 2
    elif "lower" in dn and "left" in dn:
        quadrant = 3
    elif "lower" in dn and "right" in dn:
        quadrant = 4
    else:
        return ""

    if "central incisor" in dn:
        pos = 1
    elif "lateral incisor" in dn:
        pos = 2
    elif "canine" in dn:
        pos = 3
    elif "first premolar" in dn:
        pos = 4
    elif "second premolar" in dn:
        pos = 5
    elif "first molar" in dn:
        pos = 6
    elif "second molar" in dn:
        pos = 7
    elif "third molar" in dn:
        pos = 8
    else:
        return ""

    return f"{quadrant}{pos}"

# =========================================================
# XML parser
# =========================================================
def parse_aim_xml(xml_path):

    try:
        tree = ET.parse(xml_path)
    except:
        return None

    root = tree.getroot()

    annotations = root.find("aim:imageAnnotations", NS)
    if annotations is None:
        return None

    ann = annotations.find("aim:ImageAnnotation", NS)
    if ann is None:
        return None

    tooth = ""
    surface = ""

    phys_coll = ann.find("aim:imagingPhysicalEntityCollection", NS)

    if phys_coll is not None:

        entity = phys_coll.find("aim:ImagingPhysicalEntity", NS)

        if entity is not None:

            char_coll = entity.find(
                "aim:imagingPhysicalEntityCharacteristicCollection", NS
            )

            if char_coll is not None:

                chars = char_coll.findall(
                    "aim:ImagingPhysicalEntityCharacteristic", NS
                )

                for ch in chars:

                    q_idx_el = ch.find("aim:questionIndex", NS)
                    q_idx = q_idx_el.get("value", "") if q_idx_el is not None else ""

                    tc = ch.find("aim:typeCode", NS)
                    if tc is None:
                        continue

                    code = tc.get("code", "")
                    display = _get_display_name(tc)

                    if q_idx == "0":

                        tooth = snodent_display_to_fdi(display)

                        if not tooth:
                            tooth = SNODENT_TO_FDI.get(code, "")

                    elif q_idx == "1":

                        surface = SNODENT_SURFACE_MAP.get(code, "")

                        if not surface:
                            surface = DISPLAY_NAME_TO_SURFACE.get(display, "")

    return {
        "tooth": tooth,
        "surface": surface
    }

# =========================================================
# COVERAGE CHECK
# =========================================================
base_path = Path("../data/500 cases with annotation")

ok = 0
missing_tooth = 0
missing_surface = 0
failed = 0

for case_folder in sorted(base_path.glob("case *")):

    for xml_file in case_folder.glob("*.xml"):

        parsed = parse_aim_xml(str(xml_file))

        if parsed is None:
            failed += 1
            continue

        if not parsed["tooth"]:
            missing_tooth += 1

        elif not parsed["surface"]:
            missing_surface += 1

        else:
            ok += 1

print("========== PARSE COVERAGE ==========")
print("OK lesions      :", ok)
print("Missing tooth   :", missing_tooth)
print("Missing surface :", missing_surface)
print("Failed XML      :", failed)
# Out:
# ========== PARSE COVERAGE ==========
# OK lesions      : 1979
# Missing tooth   : 0
# Missing surface : 0
# Failed XML      : 0

# %% [markdown]
# ## 5.Evaluation
#
# parse XML ground truth + parse prediction refactor mapping + parser
# ทำ evaluation:
# Accuracy
# Precision
# Recall
# F1-score
# Confusion Matrix

# %%
from pathlib import Path
import json
import pandas as pd
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

# =========================================================
# INCLUDE OTHER
# =========================================================
VALID_SURFACES = ["Occlusal", "Mesial", "Distal", "Other"]


# =========================================================
# LOAD GROUND TRUTH FROM XML
# =========================================================
def parse_case_ground_truth(case_folder):

    gt = []

    for xml_file in sorted(Path(case_folder).glob("*.xml")):

        parsed = parse_aim_xml(str(xml_file))

        if parsed is None:
            continue

        tooth = str(parsed.get("tooth", "Unknown"))
        surface = parsed.get("surface", "Other")

        if surface not in VALID_SURFACES:
            surface = "Other"

        gt.append({
            "tooth": tooth,
            "surface": surface
        })

    return gt


# =========================================================
# LOAD PREDICTION FROM PCA OUTPUT
# =========================================================
def load_prediction(case_num):

    pred_path = Path("PCA_Output") / f"case_{case_num}" / f"case_{case_num}.json"

    if not pred_path.exists():
        return []

    with open(pred_path, "r") as f:
        data = json.load(f)

    preds = []

    for t in data.get("teeth_data", []):

        tooth = str(t.get("tooth_id", "Unknown"))
        
        # ใช้ตัวแปร predicted_surface_fine ที่เป็น Class เดี่ยวแทน
        surface = t.get("predicted_surface_fine", t.get("caries_position_detail", "Other"))

        if surface not in VALID_SURFACES:
            surface = "Other"

        preds.append({
            "tooth": tooth,
            "surface": surface
        })

    return preds


# =========================================================
# MATCH GT VS PREDICTION
# =========================================================
def match_case(gt, pred):
    # Create a mapping for prediction (1 prediction per tooth usually)
    pred_dict = {
        p["tooth"]: p["surface"]
        for p in pred
    }

    y_true = []
    y_pred = []

    # 1. Iterate through every single Ground Truth lesion (Lesion-level)
    for g in gt:
        tooth = g["tooth"]
        gt_surface = g["surface"]
        
        # If the model has a prediction for this tooth, use it; else "Other"
        pred_surface = pred_dict.get(tooth, "Other")
        
        y_true.append(gt_surface)
        y_pred.append(pred_surface)

    return y_true, y_pred

# =========================================================
# MAIN LOOP
# =========================================================
all_y_true = []
all_y_pred = []

base_gt = Path("../data/500 cases with annotation")

for case_num in range(1, 501):

    gt_folder = base_gt / f"case {case_num}"

    gt = parse_case_ground_truth(gt_folder)
    pred = load_prediction(case_num)

    if len(gt) == 0 and len(pred) == 0:
        continue

    yt, yp = match_case(gt, pred)

    all_y_true.extend(yt)
    all_y_pred.extend(yp)


# =========================================================
# FINAL METRICS
# =========================================================
accuracy = accuracy_score(all_y_true, all_y_pred)

precision = precision_score(
    all_y_true,
    all_y_pred,
    average="macro",
    zero_division=0
)

recall = recall_score(
    all_y_true,
    all_y_pred,
    average="macro",
    zero_division=0
)

f1 = f1_score(
    all_y_true,
    all_y_pred,
    average="macro",
    zero_division=0
)


# =========================================================
# PRINT FINAL EVALUATION
# =========================================================
print("\n========== FINAL EVALUATION ==========")
print(f"Total Samples : {len(all_y_true)}")
print(f"Accuracy      : {accuracy:.4f}")
print(f"Precision     : {precision:.4f}")
print(f"Recall        : {recall:.4f}")
print(f"F1 Score      : {f1:.4f}")


# =========================================================
# CONFUSION MATRIX
# =========================================================
cm = confusion_matrix(
    all_y_true,
    all_y_pred,
    labels=VALID_SURFACES
)

cm_df = pd.DataFrame(
    cm,
    index=VALID_SURFACES,
    columns=VALID_SURFACES
)

print("\n========== CONFUSION MATRIX ==========")
print(cm_df)

print("\n========== CLASSIFICATION REPORT ==========")
print(
    classification_report(
        all_y_true,
        all_y_pred,
        labels=VALID_SURFACES,
        zero_division=0
    )
)
# Out:
# ========== FINAL EVALUATION ==========
# Total Samples : 1979
# Accuracy      : 0.0000
# Precision     : 0.0000
# Recall        : 0.0000
# F1 Score      : 0.0000
#
# ========== CONFUSION MATRIX ==========
#           Occlusal  Mesial  Distal  Other
# Occlusal         0       0       0    388
# Mesial           0       0       0    670
# Distal           0       0       0    921
# Other            0       0       0      0
#
# ========== CLASSIFICATION REPORT ==========
#               precision    recall  f1-score   support
#
#     Occlusal       0.00      0.00      0.00     388.0
#       Mesial       0.00      0.00      0.00     670.0
#       Distal       0.00      0.00      0.00     921.0
#        Other       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00    1979.0
#    macro avg       0.00      0.00      0.00    1979.0
# weighted avg       0.00      0.00      0.00    1979.0
